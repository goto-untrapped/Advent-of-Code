# %% [markdown]
# <a href="https://colab.research.google.com/github/goto-untrapped/Advent-of-Code/blob/main/assignments/pre5/factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fact(n):
    prod = 1
    for i in range(1, n + 1):
        prod *= i
    return prod

# %% [markdown]
# # 新しいセクション
